# %% [markdown]
# # Machine Learning Approach
# which has been achieved using Logistic Regression

# %%
import pandas as pd
import numpy as np
import warnings
import sys
import matplotlib.pyplot as plt
import csv
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# %%
def fetch_file(filename):                                           #function to fetch a file and return a list of reviews.
    try:
        with open(filename) as f:                          # or , encoding=utf8
            return [line.rstrip() for line in f if line.rstrip()]
    except IOError:
        print("Error File Does Not Exist")
        return []

# %%
df = pd.read_csv('amazon_dataset.csv')

df
# Out:
#         Rating                                             Review
# 0            5  I feel so LUCKY to have found this used (phone...
# 1            4  nice phone, nice up grade from my pantach revu...
# 2            5                                       Very pleased
# 3            4  It works good but it goes slow sometimes but i...
# 4            4  Great phone to replace my lost phone. The only...
# 5            1  I already had a phone with problems... I know ...
# 6            2  The charging port was loose. I got that solder...
# 7            2  Phone looks good but wouldn't stay charged, ha...
# 8            5  I originally was using the Samsung S2 Galaxy f...
# 9            3  It's battery life is great. It's very responsi...
# 10           3  My fiance had this phone previously, but cause...
# 11           5  This is a great product it came after two days...
# 12           5  These guys are the best! I had a little situat...
# 13           1  I'm really disappointed about my phone and ser...
# 14           5  Ordered this phone as a replacement for the sa...
# 15           2  Had this phone before and loved it but was not...
# 16           5  I was able to get the phone I previously owned...
# 17           5  I brought this phone as a replacement for my d...
# 18           4  I love the phone. It does everything I need an...
# 19           3  unfortunately Sprint could not activate the ph...
# 20           4  The battery was old & had been over used becau...
# 21           4  pros-beautiful screen,capable of running chrom...
# 22           1  I purchased this phone in December as a christ...
# 23           4  Phone good just a little slow phone old but it...
# 24           4  Phone's speaker little low. Overall very happy...
# 25           5  the phone was great and in good condition. My ...
# 26           3  the reasons for the 3 star rating was it was i...
# 27           5              Phone works great. No problems at all
# 28           1       was not in good condition but does work good
# 29           1  Just... not good. The phone has great screen r...
# ...        ...                                                ...
# 413810       4  I purchased the Samsung Convoy U640 for my eld...
# 413811       5  My husband wanted rugged pho?ne for work. He i...
# 413812       5  I never bought from Amazon before , but I real...
# 413813       4  Iv'e never quite got used to the iphone and dr...
# 413814       5  This is by far the best flip phone out there. ...
# 413815       5  This phone is simple, very good , and it works...
# 413816       4  Good sturdy phone for a pre-teen to have avail...
# 413817       1  This is the second junk Convoy I have owned. T...
# 413818       3  This cell phone provides the just the service ...
# 413819       5  I BOUGHT THIS PHONE FOR MY HUSBAND AND HE LOVE...
# 413820       1  They said phone was normal wear but it was a l...
# 413821       5  You could shoot this out of a potato gun, and ...
# 413822       5  Bought this for my mother and she loves it. Gr...
# 413823       5  Excellent phone, as advertised. Love the push-...
# 413824       4  works great and picks up signal in place my ot...
# 413825       5  Great phone. Large keys, best flip phone I hav...
# 413826       5  Pros...Works great, very durable, easy to navi...
# 413827       5            just as described perfect for the price
# 413828       1                                     Would not work
# 413829       3   Speaker phone doesn't work, but phone works good
# 413830       5                                            LOVE IT
# 413831       1  Item was listed as new, but was not. When we t...
# 413832       4  good rugged phone that has a long-lasting batt...
# 413833       3                                  The phone is good
# 413834       1                                          used hard
# 413835       5                     another great deal great price
# 413836       3                                                 Ok
# 413837       5        Passes every drop test onto porcelain tile!
# 413838       3  I returned it because it did not meet my needs...
# 413839       4  Only downside is that apparently Verizon no lo...
#
# [413840 rows x 2 columns]

# %%
df.dropna(inplace=True)                #Dropping empty cells if there are any.

# %%
df = df[df['Rating']!=3]               #Dropping reviews with rating =3

# %%
df
# Out:
#         Rating                                             Review
# 0            5  I feel so LUCKY to have found this used (phone...
# 1            4  nice phone, nice up grade from my pantach revu...
# 2            5                                       Very pleased
# 3            4  It works good but it goes slow sometimes but i...
# 4            4  Great phone to replace my lost phone. The only...
# 5            1  I already had a phone with problems... I know ...
# 6            2  The charging port was loose. I got that solder...
# 7            2  Phone looks good but wouldn't stay charged, ha...
# 8            5  I originally was using the Samsung S2 Galaxy f...
# 11           5  This is a great product it came after two days...
# 12           5  These guys are the best! I had a little situat...
# 13           1  I'm really disappointed about my phone and ser...
# 14           5  Ordered this phone as a replacement for the sa...
# 15           2  Had this phone before and loved it but was not...
# 16           5  I was able to get the phone I previously owned...
# 17           5  I brought this phone as a replacement for my d...
# 18           4  I love the phone. It does everything I need an...
# 20           4  The battery was old & had been over used becau...
# 21           4  pros-beautiful screen,capable of running chrom...
# 22           1  I purchased this phone in December as a christ...
# 23           4  Phone good just a little slow phone old but it...
# 24           4  Phone's speaker little low. Overall very happy...
# 25           5  the phone was great and in good condition. My ...
# 27           5              Phone works great. No problems at all
# 28           1       was not in good condition but does work good
# 29           1  Just... not good. The phone has great screen r...
# 30           5                           as described, fast ship!
# 31           5                              Perfect in every way.
# 32           2  One of the phones have a bad charger port. I w...
# 33           5  Just got this phone and it is a great phone. I...
# ...        ...                                                ...
# 413805       5  first phone did not work i called them and the...
# 413806       5  Great phone for the person who needs to make c...
# 413807       1  I purchased this phone on 6/13/2013. Upon rece...
# 413808       4  The phone was decent and came as expected. How...
# 413809       5  I like this phone for the larger buttons for t...
# 413810       4  I purchased the Samsung Convoy U640 for my eld...
# 413811       5  My husband wanted rugged pho?ne for work. He i...
# 413812       5  I never bought from Amazon before , but I real...
# 413813       4  Iv'e never quite got used to the iphone and dr...
# 413814       5  This is by far the best flip phone out there. ...
# 413815       5  This phone is simple, very good , and it works...
# 413816       4  Good sturdy phone for a pre-teen to have avail...
# 413817       1  This is the second junk Convoy I have owned. T...
# 413819       5  I BOUGHT THIS PHONE FOR MY HUSBAND AND HE LOVE...
# 413820       1  They said phone was normal wear but it was a l...
# 413821       5  You could shoot this out of a potato gun, and ...
# 413822       5  Bought this for my mother and she loves it. Gr...
# 413823       5  Excellent phone, as advertised. Love the push-...
# 413824       4  works great and picks up signal in place my ot...
# 413825       5  Great phone. Large keys, best flip phone I hav...
# 413826       5  Pros...Works great, very durable, easy to navi...
# 413827       5            just as described perfect for the price
# 413828       1                                     Would not work
# 413830       5                                            LOVE IT
# 413831       1  Item was listed as new, but was not. When we t...
# 413832       4  good rugged phone that has a long-lasting batt...
# 413834       1                                          used hard
# 413835       5                     another great deal great price
# 413837       5        Passes every drop test onto porcelain tile!
# 413839       4  Only downside is that apparently Verizon no lo...
#
# [382015 rows x 2 columns]

# %%
pd.options.mode.chained_assignment = None
df['Polarity'] = np.where(df['Rating'] > 3, 1,0)

# %%
df
# Out:
#         Rating                                             Review  Polarity
# 0            5  I feel so LUCKY to have found this used (phone...         1
# 1            4  nice phone, nice up grade from my pantach revu...         1
# 2            5                                       Very pleased         1
# 3            4  It works good but it goes slow sometimes but i...         1
# 4            4  Great phone to replace my lost phone. The only...         1
# 5            1  I already had a phone with problems... I know ...         0
# 6            2  The charging port was loose. I got that solder...         0
# 7            2  Phone looks good but wouldn't stay charged, ha...         0
# 8            5  I originally was using the Samsung S2 Galaxy f...         1
# 11           5  This is a great product it came after two days...         1
# 12           5  These guys are the best! I had a little situat...         1
# 13           1  I'm really disappointed about my phone and ser...         0
# 14           5  Ordered this phone as a replacement for the sa...         1
# 15           2  Had this phone before and loved it but was not...         0
# 16           5  I was able to get the phone I previously owned...         1
# 17           5  I brought this phone as a replacement for my d...         1
# 18           4  I love the phone. It does everything I need an...         1
# 20           4  The battery was old & had been over used becau...         1
# 21           4  pros-beautiful screen,capable of running chrom...         1
# 22           1  I purchased this phone in December as a christ...         0
# 23           4  Phone good just a little slow phone old but it...         1
# 24           4  Phone's speaker little low. Overall very happy...         1
# 25           5  the phone was great and in good condition. My ...         1
# 27           5              Phone works great. No problems at all         1
# 28           1       was not in good condition but does work good         0
# 29           1  Just... not good. The phone has great screen r...         0
# 30           5                           as described, fast ship!         1
# 31           5                              Perfect in every way.         1
# 32           2  One of the phones have a bad charger port. I w...         0
# 33           5  Just got this phone and it is a great phone. I...         1
# ...        ...                                                ...       ...
# 413805       5  first phone did not work i called them and the...         1
# 413806       5  Great phone for the person who needs to make c...         1
# 413807       1  I purchased this phone on 6/13/2013. Upon rece...         0
# 413808       4  The phone was decent and came as expected. How...         1
# 413809       5  I like this phone for the larger buttons for t...         1
# 413810       4  I purchased the Samsung Convoy U640 for my eld...         1
# 413811       5  My husband wanted rugged pho?ne for work. He i...         1
# 413812       5  I never bought from Amazon before , but I real...         1
# 413813       4  Iv'e never quite got used to the iphone and dr...         1
# 413814       5  This is by far the best flip phone out there. ...         1
# 413815       5  This phone is simple, very good , and it works...         1
# 413816       4  Good sturdy phone for a pre-teen to have avail...         1
# 413817       1  This is the second junk Convoy I have owned. T...         0
# 413819       5  I BOUGHT THIS PHONE FOR MY HUSBAND AND HE LOVE...         1
# 413820       1  They said phone was normal wear but it was a l...         0
# 413821       5  You could shoot this out of a potato gun, and ...         1
# 413822       5  Bought this for my mother and she loves it. Gr...         1
# 413823       5  Excellent phone, as advertised. Love the push-...         1
# 413824       4  works great and picks up signal in place my ot...         1
# 413825       5  Great phone. Large keys, best flip phone I hav...         1
# 413826       5  Pros...Works great, very durable, easy to navi...         1
# 413827       5            just as described perfect for the price         1
# 413828       1                                     Would not work         0
# 413830       5                                            LOVE IT         1
# 413831       1  Item was listed as new, but was not. When we t...         0
# 413832       4  good rugged phone that has a long-lasting batt...         1
# 413834       1                                          used hard         0
# 413835       5                     another great deal great price         1
# 413837       5        Passes every drop test onto porcelain tile!         1
# 413839       4  Only downside is that apparently Verizon no lo...         1
#
# [382015 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, x_test, Y_train, Y_test = train_test_split(df['Review'], df['Polarity'], random_state=0)

# %%
X_train[20]
# Out:
# 'The battery was old & had been over used because it barely holds a charge. Otherwise, no issues with the phone itself.'

# %%
X_train[100]
# Out:
# 'excelente'

# %%
X_train.shape
# Out:
# (286511,)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer().fit(X_train)

# %%
vect.get_feature_names()[::2000]
# Out:
# ['00',
#  '3the',
#  'acdc',
#  'aplicaciones',
#  'battety',
#  'burla',
#  'cingularproxy',
#  'corazon',
#  'demás',
#  'droid',
#  'ev',
#  'flaps',
#  'goe',
#  'hmmmmmmm',
#  'insuperable',
#  'lad',
#  'managerbackupbrowsercalculatorcalendarcaller',
#  'mounted',
#  'occassionaly',
#  'peasy',
#  'predecessor',
#  'rambo',
#  'responsebest',
#  'sections',
#  'sneer',
#  'suit',
#  'thrall',
#  'undesired',
#  'vã',
#  'yeahhhh']

# %%
len(vect.get_feature_names())
# Out:
# 58585

# %%
X_train_vectorized = vect.transform(X_train)

X_train_vectorized
# Out:
# <286511x58585 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7545211 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)
model.fit(X_train_vectorized, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
from sklearn.metrics import roc_auc_score
# Any words in X_test that didn't appeared in X_train will be ignored 
predictions = model.predict(vect.transform(x_test))
roc_auc_score(Y_test, predictions)
# Out:
# 0.9695323735868064

# %%
vect = CountVectorizer(min_df=5, ngram_range=(1,2)).fit(X_train)

X_train_vectorized = vect.transform(X_train)

len(vect.get_feature_names())
# Out:
# 234662

# %%
model = LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)
model.fit(X_train_vectorized, Y_train)

predictions = model.predict(vect.transform(x_test))

#print('AUC: ', roc_auc_score(Y_test, predictions))

# %%
print(model.predict(vect.transform(['not an issue, phone is working',
                                    'an issue, phone is not working'])))
# Out:
# [1 0]

# %% [markdown]
# # Model Application
# Now since our model is trained, we can give real world data to it for interpretation.
# Here we use the dataset of the phone
# ### Oppo F11 Pro

# %%
Lines = fetch_file("OppoF11Pro.txt")
Lines[0]
# Out:
# 'This is amazing powerful and beautiful fon from oppo best camera, battery, design, display, sound quality, processor'

# %%
pos_count = 0
neg_count = 0

for i in range(0, len(Lines)):
    flag = int(model.predict(vect.transform([Lines[i]])))
    if(flag == 1):
        pos_count = pos_count+1
    else:
        neg_count = neg_count+1
        
print(pos_count, neg_count)
# Out:
# 132 51

# %%
positive_polarity = (pos_count/(pos_count + neg_count))
print("Positive Polarity: ", positive_polarity)
negative_polarity = (neg_count/(pos_count + neg_count))
print("Negative Polarity: ", negative_polarity)
# Out:
# Positive Polarity:  0.7213114754098361
# Negative Polarity:  0.2786885245901639

# %%
labels = 'Positvity', 'Negativity'
sizes = [(positive_polarity*100), (negative_polarity*100)]
explode = (0, 0.1)  
colours = ['lightskyblue', 'lightcoral']

fig1, ax1 = plt.subplots()
fig = plt.gcf() ########################################################
fig.set_size_inches(10,10)
ax1.pie(sizes, colors=colours, explode=explode, labels=labels, autopct='%1.2f%%',  shadow=True, startangle=140)
ax1.axis('equal') 
ax1.set_title("Polarity Ratio")

plt.show()

# %%
positive_list = []

with open('pos_words.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        positive_list.append(row)

negative_list = []

with open('neg_words.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        negative_list.append(row)

# %%
for i in range(0,len(Lines)):
    Lines[i] = Lines[i].lower()

stop_wordset = set(stopwords.words('english'))
stop_wordset.add('.')  #Add more symbols and numbers to remove from the data.
stop_wordset #180 wordset



Tokens = [] #List of words for CountVectorization

for i in range(0,len(Lines)):
    
    word_tokens = word_tokenize(Lines[i]) 
  
    filtered_sentence = [w for w in word_tokens if not w in stop_wordset] 
  
    filtered_sentence = [] 
  
    for w in word_tokens: 
        if w not in stop_wordset: 
            filtered_sentence.append(w)
            Tokens.append(w)    
    

    
vectorizer = CountVectorizer(min_df=0, lowercase=False)
vectorizer.fit(Tokens)
Bag_of_Words = list(vectorizer.vocabulary_)
# Out:
# ['this', 'is', 'amazing', 'powerful', 'and', 'beautiful', 'fon', 'from', 'oppo', 'best', 'camera', ',', 'battery', ',', 'design', ',', 'display', ',', 'sound', 'quality', ',', 'processor']
# ['amazing', 'powerful', 'beautiful', 'fon', 'oppo', 'best', 'camera', ',', 'battery', ',', 'design', ',', 'display', ',', 'sound', 'quality', ',', 'processor']
# ['i', 'bought', 'this', 'device', 'on', 'release', 'date', 'itself', 'im', 'loving', 'it', 'i', 'just', 'want', 'to', 'say', 'cons', 'bcoz', 'it', 'has', 'lot', 'of', 'pros', ',', 'rear', 'camera', 'should', 'improve', 'a', 'little', 'bit', 'it', 'produces', 'over', 'saturation', 'images', 'and', 'their', 'is', 'no', 'eis', 'i', 'hope', 'they', 'will', 'fix', 'that', 'via', 'ota', 'update']
# ['bought', 'device', 'release', 'date', 'im', 'loving', 'want', 'say', 'cons', 'bcoz', 'lot', 'pros', ',', 'rear', 'camera', 'improve', 'little', 'bit', 'produces', 'saturation', 'images', 'eis', 'hope', 'fix', 'via', 'ota', 'update']
# ['i', 'just', 'got', 'it', '3hours', 'back..', 'and', 'guess', 'what', 'the', 'look', 'of', 'the', 'mobile', 'is', 'extremely', 'premium', '.', 'and', 'the', 'build', 'quality', 'is', 'awesome', '.', 'camera', 'is', 'quite', 'good', '.', 'this', 'is', 'my', 'first', 'review', 'for', 'this', 'mobile', '.']
# ['got', '3hours', 'back..', 'guess', 'look', 'mobile', 'extremely', 'premium', 'build', 'quality', 'awesome', 'camera', 'quite', 'good', 'first', 'review', 'mobile']
# ['i', 'have', 'been', 'using', 'this', 'phone', 'for', 'the', 'past', '5', 'days', '.', 'i', 'observe', 'a', 'lag', 'when', 'i', 'browse', 'through', 'photos', 'while', 'using', 'google', 'photos', 'and', 'also', 'for', 'some', 'reason', 'my', 'youtube', 'videos', 'are', 'being', 'set', 'at', 'low', 'quality', ',', 'by', 'any', 'means', 'i', 'am', 'not', 'able', 'to', 'change', 'it', '.', 'camera', 'quality', 'does', 'not', 'seem', 'to', 'be', 'good', ',', 'too', 'much', 'of', 'colour', 'in', 'the', 'output', 'and', 'the', 'pictures', 'does', 'not', 'seem', 'natural', '.']
# ['using', 'phone', 'past', '5', 'days', 'observe', 'lag', 'browse', 'photos', 'using', 'google', 'photos', 'also', 'reason', 'youtube', 'videos', 'set', 'low', 'quality', ',', 'means', 'able', 'change', 'camera', 'quality', 'seem', 'good', ',', 'much', 'colour', 'output', 'pictures', 'seem', 'natural']
# ['amazon', 'service', 'quality', 'can', 'be', 'compared', 'to', 'bsnl', 'or', 'other', 'semi', 'govt', 'entity', '.', 'during', 'the', 'delivery', 'processes', 'itself', ',', 'the', 'delivery', 'date', 'was', 'deferred', '4', 'times', 'and', 'the', 'customer', 'care', 'staff', 'was', "n't", 'hesitant', 'to', 'provide', 'delivery', 'assurance', 'on', 'the', 'same', 'day', 'for', 'all', 'calls', 'i', 'made', 'regarding', 'the', 'concern', '.']
# ['amazon', 'service', 'quality', 'compared', 'bsnl', 'semi', 'govt', 'entity', 'delivery', 'processes', ',', 'delivery', 'date', 'deferred', '4', 'times', 'customer', 'care', 'staff', "n't", 'hesitant', 'provide', 'delivery', 'assurance', 'day', 'calls', 'made', 'regarding', 'concern']
# ['everything', 'in', 'this', 'phone', 'is', 'pretty', 'except', 'for', 'some', 'features', 'but', 'we', 'can', 'manage', 'that', ',', 'now', 'the', 'main', 'problem', 'is', 'its', 'display', 'tech', '.', 'guys', '.', 'it', 'is', 'the', 'cheapest', 'display', 'tech', '.', 'which', 'is', 'used', 'in', 'this', 'phone', '(', 'tft', 'display', ')', '.', 'the', 'main', 'thing', 'about', 'phone', 'is', 'display', '.', 'due', 'to', 'the', 'display', 'everything', 'you', 'see', 'whether', 'it', 'is', 'a', 'video', 'or', 'you', 'play', 'a', 'ge', ',', 'they', 'are', 'of', 'entirely', 'different', 'colours', '.', 'ofcourse', 'if', 'you', 'compare', 'with', 'other', 'phone', 'you', 'will', 'see', '.', 'but', 'to', 'compare', 'you', 'need', 'to', 'buy', 'and', 'amazon', 'people', 'wo', "n't", 'return', 'your', 'money', 'back', '.']
# ['everything', 'phone', 'pretty', 'except', 'features', 'manage', ',', 'main', 'problem', 'display', 'tech', 'guys', 'cheapest', 'display', 'tech', 'used', 'phone', '(', 'tft', 'display', ')', 'main', 'thing', 'phone', 'display', 'due', 'display', 'everything', 'see', 'whether', 'video', 'play', 'ge', ',', 'entirely', 'different', 'colours', 'ofcourse', 'compare', 'phone', 'see', 'compare', 'need', 'buy', 'amazon', 'people', 'wo', "n't", 'return', 'money', 'back']
# ['camera', 'is', 'too', 'bad', 'and', 'youtube', 'videos', 'quality', 'even', '1080p', 'also', 'not', 'good', '.', 'colours', 'reproduction', 'is', 'too', 'bad', 'in', 'camera', '.', 'slow', 'motion', 'camera', 'whey', 'oppo', 'highlighted', 'in', 'launch', 'event', 'nothing', 'in', 'slow', 'motion', 'camera', 'i', 'am', 'very', 'disappointed', 'in', 'that', 'section', 'and', 'slow', 'motion', 'camera', 'is', 'purely', 'for', 'pulblcity', '.', 'video', 'department', 'also', 'colours', 'not', 'good', '.', 'battery', 'life', 'is', 'average', '.', 'design', 'and', 'build', 'looking', 'like', 'premium', 'phone', '.', 'i', 'do', "n't", 'recommend', 'this', 'mobile', 'to', 'anyone', '.', 'i', 'raised', 'a', 'concern', 'on', 'twitter', 'also', 'but', 'those', 'guys', 'are', 'very', 'irresponsible', 'persons', 'nobody', 'is', 'taking', 'care', 'about', 'our', 'concerns']
# ['camera', 'bad', 'youtube', 'videos', 'quality', 'even', '1080p', 'also', 'good', 'colours', 'reproduction', 'bad', 'camera', 'slow', 'motion', 'camera', 'whey', 'oppo', 'highlighted', 'launch', 'event', 'nothing', 'slow', 'motion', 'camera', 'disappointed', 'section', 'slow', 'motion', 'camera', 'purely', 'pulblcity', 'video', 'department', 'also', 'colours', 'good', 'battery', 'life', 'average', 'design', 'build', 'looking', 'like', 'premium', 'phone', "n't", 'recommend', 'mobile', 'anyone', 'raised', 'concern', 'twitter', 'also', 'guys', 'irresponsible', 'persons', 'nobody', 'taking', 'care', 'concerns']
# ['i', 'have', 'this', 'phn', '(', '4/64', 'version', ')', '.', 'overall', 'performance', 'is', 'good', '.', 'camera', 'is', 'decent', 'at', 'this', 'price', 'point', '.', 'but', 'the', 'speaker', "'s", 'quality', 'is', 'too', 'bad', '.', 'even', 'after', 'full', 'volume', 'the', 'speaker', "'s", 'sound', 'is', 'too', 'low', 'which', 'really', 'disappoint', 'me', '.', 'otherwise', 'the', 'device', 'is', 'really', 'good', '.']
# ['phn', '(', '4/64', 'version', ')', 'overall', 'performance', 'good', 'camera', 'decent', 'price', 'point', 'speaker', "'s", 'quality', 'bad', 'even', 'full', 'volume', 'speaker', "'s", 'sound', 'low', 'really', 'disappoint', 'otherwise', 'device', 'really', 'good']
# ['very', 'poor', 'network', ',', 'bad', 'sound', 'quality', ',', 'bad', 'network', 'quality', ',', 'camera', 'is', 'too', 'dull', ',', 'pls', 'amazon', 'you', 'are', 'one', 'of', 'the', 'good', 'online', 'shopping', 'centre', 'pls', 'do', "n't", 'show', 'faulty', 'piece', 'and', 'faulty', 'products..']
# ['poor', 'network', ',', 'bad', 'sound', 'quality', ',', 'bad', 'network', 'quality', ',', 'camera', 'dull', ',', 'pls', 'amazon', 'one', 'good', 'online', 'shopping', 'centre', 'pls', "n't", 'show', 'faulty', 'piece', 'faulty', 'products..']
# ['it', 'is', 'disaster', 'phone', 'on', '2nd', 'day', 'itself', 'i', 'was', 'not', 'able', 'to', 'hear', 'a', 'voice', 'of', 'person', 'during', 'calls', 'very', 'very', 'very', 'very', 'poor', 'call', 'quality', 'display', 'is', 'worstest', 'i', 'ever', 'seen', 'on', 'any', 'phone', 'the', 'screen', 'gesture', 'function', 'is', 'also', 'not', 'their', 'i', 'do', "n't", 'no', 'what', 'amazon', 'has', 'sended', 'might', 'be', 'it', 'is', 'faulty', 'piece', 'bttr', 'go', 'for', 'some', 'other', 'phone', 'than', 'this', 'crap']
# ['disaster', 'phone', '2nd', 'day', 'able', 'hear', 'voice', 'person', 'calls', 'poor', 'call', 'quality', 'display', 'worstest', 'ever', 'seen', 'phone', 'screen', 'gesture', 'function', 'also', "n't", 'amazon', 'sended', 'might', 'faulty', 'piece', 'bttr', 'go', 'phone', 'crap']
# ['product', 'is', 'good', 'in', 'the', 'view', 'of', 'camera', 'and', 'all', 'the', 'features', '.', 'dual', 'volte', 'is', 'the', 'ultimate', 'feature', '.']
# ['product', 'good', 'view', 'camera', 'features', 'dual', 'volte', 'ultimate', 'feature']
# ['but', 'the', 'phone', 'is', 'unable', 'to', 'access', 'the', 'memory', 'card', ',', 'when', 'you', 'set', 'the', 'default', 'storage', 'as', 'memory', 'card', ',', 'even', 'if', 'you', 'take', 'the', '05', 'sec', 'video', 'also', ',', 'phone', 'is', 'unable', 'to', 'store', 'the', 'data', 'to', 'memory', 'card', 'and', 'with', 'in', 'seconds', 'the', 'device', 'is', 'going', 'into', 'blank', 'condition', '.']
# ['phone', 'unable', 'access', 'memory', 'card', ',', 'set', 'default', 'storage', 'memory', 'card', ',', 'even', 'take', '05', 'sec', 'video', 'also', ',', 'phone', 'unable', 'store', 'data', 'memory', 'card', 'seconds', 'device', 'going', 'blank', 'condition']
# ['i', 'can', 'clearly', 'say', 'that', ',', 'that', 'is', 'not', 'the', 'memory', 'card', 'problem', ',', 'because', 'the', 'same', 'memory', 'card', 'is', 'getting', 'good', 'access', 'and', 'good', 'functioning', 'in', 'other', 'mobiles', '.']
# ['clearly', 'say', ',', 'memory', 'card', 'problem', ',', 'memory', 'card', 'getting', 'good', 'access', 'good', 'functioning', 'mobiles']
# ['so', ',', 'after', 'knowing', 'this', 'i', 'formatted', 'my', 'memory', 'card', 'and', 'tried', 'take', 'store', 'the', 'another', 'video', 'file', 'by', 'setting', 'the', 'storage', 'as', 'default', 'location', 'memory', ',', 'but', 'again', 'it', 'is', 'showing', 'the', 'same', 'blank', 'condition', '.']
# [',', 'knowing', 'formatted', 'memory', 'card', 'tried', 'take', 'store', 'another', 'video', 'file', 'setting', 'storage', 'default', 'location', 'memory', ',', 'showing', 'blank', 'condition']
# ['disappointed', 'due', 'to', 'direct', 'storage', 'issue']
# ['disappointed', 'due', 'direct', 'storage', 'issue']
# ['purchase', 'my', 'first', 'oppo', 'phone', ',', 'great', 'display', ',', 'great', 'performance', ',', 'great', 'build', 'quality', 'over', 'all', 'good', 'phone', '.']
# ['purchase', 'first', 'oppo', 'phone', ',', 'great', 'display', ',', 'great', 'performance', ',', 'great', 'build', 'quality', 'good', 'phone']
# ['the', 'product', 'is', 'awesome', 'as', 'i', 'heard', '...', 'but', 'the', 'quality', 'check', 'failure', 'ruined', 'its', 'charm', '.', 'received', 'a', 'set', 'with', 'scratches', 'and', 'hairline', 'on', 'its', 'display', '.', 'now', 'i', 'even', 'doubt', 'its', 'genuinity', '!', '!', 'gon', 'na', 'ask', 'for', 'my', 'refund', 'back', 'to', 'me', '.']
# ['product', 'awesome', 'heard', '...', 'quality', 'check', 'failure', 'ruined', 'charm', 'received', 'set', 'scratches', 'hairline', 'display', 'even', 'doubt', 'genuinity', '!', '!', 'gon', 'na', 'ask', 'refund', 'back']
# ['this', 'phone', 'has', 'excellent', 'features', 'but', 'fails', 'in', 'the', 'audio', 'department', '.', 'missing', 'my', 'exchanged', 'lenovo', 'k4', 'note', 'with', 'dolby', 'atmos', '&', 'stereo', 'speakers', '...']
# ['phone', 'excellent', 'features', 'fails', 'audio', 'department', 'missing', 'exchanged', 'lenovo', 'k4', 'note', 'dolby', 'atmos', '&', 'stereo', 'speakers', '...']
# ['very', 'downgraded', 'camera..', 'oppo', 'f11', 'pro', 'failed', 'with', 'the', 'so', 'called', '20mp', 'dual', 'camera', '.', 'saturation', 'levels', 'can', 'not', 'be', 'compared', 'even', 'with', 'a', '2mp', 'camera', 'phone', '.', 'often', 'the', 'pictures', 'taken', 'are', 'very', 'very', 'unrealistic', '.', 'sees', 'like', 'the', 'ai', 'function', 'is', 'pathetic', '.', 'eis', 'is', 'a', 'definite', 'miss', '.', 'slow', 'motion', 'camera', 'is', 'also', 'a', 'failure', '.', 'can', '’', 't', 'recognize', 'the', 'moving', 'objects', 'clearly', '.', 'video', 'play', 'back', 'is', 'also', 'not', 'that', 'good', '.', 'youtube', 'videos', 'in', 'fully', 'screen', 'lacks', 'clarity', '.', 'a', 'number', 'of', 'time', 'the', 'camera', 'setting', 'were', 'changed', 'to', 'default', '.', 'but', 'of', 'no', 'use.', ',', 'hope', 'the', 'company', 'may', 'rollout', 'few', 'updates', 'to', 'rectify', 'these', 'basic', 'issues', '.']
# ['downgraded', 'camera..', 'oppo', 'f11', 'pro', 'failed', 'called', '20mp', 'dual', 'camera', 'saturation', 'levels', 'compared', 'even', '2mp', 'camera', 'phone', 'often', 'pictures', 'taken', 'unrealistic', 'sees', 'like', 'ai', 'function', 'pathetic', 'eis', 'definite', 'miss', 'slow', 'motion', 'camera', 'also', 'failure', '’', 'recognize', 'moving', 'objects', 'clearly', 'video', 'play', 'back', 'also', 'good', 'youtube', 'videos', 'fully', 'screen', 'lacks', 'clarity', 'number', 'time', 'camera', 'setting', 'changed', 'default', 'use.', ',', 'hope', 'company', 'may', 'rollout', 'updates', 'rectify', 'basic', 'issues']
# ['oppo', 'f11', 'pro', 'is', 'not', 'a', 'camera', 'phone', '.', 'in', 'oppo', 'f11', 'pro', 'all', 'features', 'are', 'good', 'but', 'camera', 'is', 'not', 'as', 'excepted', '.', 'front', 'camera', 'and', 'indoor', 'photo', 'quality', 'of', 'both', 'front', 'and', 'rear', 'camera', 'is', 'disgusting', '.beautify', 'mode', 'is', 'not', 'good', 'as', 'other', 'mobiles', 'provided', '.', 'it', 'may', 'required', 'update', 'from', 'honor', '.']
# ['oppo', 'f11', 'pro', 'camera', 'phone', 'oppo', 'f11', 'pro', 'features', 'good', 'camera', 'excepted', 'front', 'camera', 'indoor', 'photo', 'quality', 'front', 'rear', 'camera', 'disgusting', '.beautify', 'mode', 'good', 'mobiles', 'provided', 'may', 'required', 'update', 'honor']
# ['battery', 'drains', 'so', 'fast', 'while', 'playing', 'games', 'and', 'using', 'the', 'camera', 'too', '.']
# ['battery', 'drains', 'fast', 'playing', 'games', 'using', 'camera']
# ['applied', 'for', 'replacement.hoping', 'the', 'new', 'one', 'will', 'have', 'better', 'battery', 'life']
# ['applied', 'replacement.hoping', 'new', 'one', 'better', 'battery', 'life']
# ['edit-got', 'the', 'replacement', 'today', '.', 'this', 'one', 'is', 'also', 'defective', '.', 'the', 'back', 'panel', 'is', 'bulged', 'opened', '.', '~gona', 'replace', 'again', 'hope', 'next', 'time', 'i', 'will', 'get', 'a', 'good', 'condition', 'product~', 'no', 'third', 'time', 'replacement', 'such', 'waste', 'of', 'time', '...', 'amazon', 'guys', 'are', 'doinga']
# ['edit-got', 'replacement', 'today', 'one', 'also', 'defective', 'back', 'panel', 'bulged', 'opened', '~gona', 'replace', 'hope', 'next', 'time', 'get', 'good', 'condition', 'product~', 'third', 'time', 'replacement', 'waste', 'time', '...', 'amazon', 'guys', 'doinga']
# ['bad', 'service', 'to', 'customers']
# ['bad', 'service', 'customers']
# ['very', 'pathetic', 'battery', 'life', '.', 'hardly', 'runs', 'for', '12', 'hrs', 'with', 'moderate', 'usage', '.']
# ['pathetic', 'battery', 'life', 'hardly', 'runs', '12', 'hrs', 'moderate', 'usage']
# ['on', 'top', 'of', 'that', 'this', 'phone', 'has', 'super', 'efficient', 'memory', 'management', 'it', 'does', "n't", 'even', 'keep', 'an', 'app', 'in', 'background', 'for', 'even', '1', 'second', '.like', 'you', 'switch', 'between', 'apps', 'and', 'you', 'lost', 'the', 'state', 'in', 'old', 'app', ',', 'and', 'have', 'to', 'start', 'from', 'all', 'over', 'again', '.']
# ['top', 'phone', 'super', 'efficient', 'memory', 'management', "n't", 'even', 'keep', 'app', 'background', 'even', '1', 'second', '.like', 'switch', 'apps', 'lost', 'state', 'old', 'app', ',', 'start']
# ['with', 'such', 'super', 'efficient', 'battery', 'management', 'it', 'should', 'have', 'be', 'giving', 'more', 'battery', 'backup', 'but', 'it', 'looks', 'like', 'to', 'be', 'working', 'against', 'it', '.']
# ['super', 'efficient', 'battery', 'management', 'giving', 'battery', 'backup', 'looks', 'like', 'working']
# ['this', 'is', 'very', 'classy', 'product', 'from', 'this', 'budget', '.', 'great', 'value', 'for', 'money', '.', 'jet', 'speed', 'performance', ',', 'battery', 'is', 'a', 'beast', '.', 'camera', 'is', 'ultimate', '.', 'everyone', 'is', 'asking', 'me', 'is', 'this', 'honor', ',', 'looks', 'wow', '.']
# ['classy', 'product', 'budget', 'great', 'value', 'money', 'jet', 'speed', 'performance', ',', 'battery', 'beast', 'camera', 'ultimate', 'everyone', 'asking', 'honor', ',', 'looks', 'wow']
# ['as', 'of', 'now', ',', 'its', 'been', '3', 'days', 'after', 'the', 'purchase', 'i', 'sharing', 'this', 'review', 'of', 'oppo', 'f11', 'pro..', 'there', 'is', 'no', 'lagging', 'in', 'performance', 'and', 'design', 'is', 'undoubtedly', 'superb', '.', 'battery', 'life', 'is', 'very', 'good', 'as', 'it', 'stands', 'for', '1', 'and', 'half', 'day', 'with', 'good', 'usage', '.', 'in', 'this', 'mid', 'range', 'oppo', 'f11', 'pro', 'is', 'totally', 'value', 'for', 'money', '.']
# [',', '3', 'days', 'purchase', 'sharing', 'review', 'oppo', 'f11', 'pro..', 'lagging', 'performance', 'design', 'undoubtedly', 'superb', 'battery', 'life', 'good', 'stands', '1', 'half', 'day', 'good', 'usage', 'mid', 'range', 'oppo', 'f11', 'pro', 'totally', 'value', 'money']
# ['picture', 'quality', 'is', 'awful', '.', 'i', 'ca', "n't", 'understand', 'how', 'different', 'techies', 'on', 'you', 'tube', 'provided', 'such', 'a', 'good', 'feedback', '.', 'the', 'camera', 'is', 'hell', ',', 'selfie', 'loving', 'guys', 'is', 'gon', 'na', 'hate', 'it', '.', 'primary', 'camera', 'only', 'good', 'if', 'held', 'still', '.', 'youtube', 'videos', 'i', 'compared', 'to', 'my', '1plus', '3t', 'and', 'i', 'can', 'see', 'a', 'huge', 'difference', 'in', 'the', 'quality', 'and', 'color', '.', 'battery', 'backup', 'is', 'good', ',', 'design', 'is', 'unmatchable', 'at', 'this', 'price', 'range', ',', 'display', 'size', 'is', 'good', 'but', 'the', 'display', 'quality', 'is', 'cheap', '.', 'i', 'would', 'recommend', 'not', 'buying', 'this', 'phone', 'and', 'rather', 'go', 'for', 'note', '5', 'pro', 'which', 'has', 'better', 'camera', 'and', 'better', 'display', 'and', 'comes', 'about', '2500', 'cheaper', 'than', 'this', 'phone', '.', 'if', 'looks', 'and', 'design', 'is', 'all', 'you', 'are', 'looking', 'for', '..then', 'oppo', 'f11', 'pro', 'is', 'the', 'best', 'phone', 'for', 'u']
# ['picture', 'quality', 'awful', 'ca', "n't", 'understand', 'different', 'techies', 'tube', 'provided', 'good', 'feedback', 'camera', 'hell', ',', 'selfie', 'loving', 'guys', 'gon', 'na', 'hate', 'primary', 'camera', 'good', 'held', 'still', 'youtube', 'videos', 'compared', '1plus', '3t', 'see', 'huge', 'difference', 'quality', 'color', 'battery', 'backup', 'good', ',', 'design', 'unmatchable', 'price', 'range', ',', 'display', 'size', 'good', 'display', 'quality', 'cheap', 'would', 'recommend', 'buying', 'phone', 'rather', 'go', 'note', '5', 'pro', 'better', 'camera', 'better', 'display', 'comes', '2500', 'cheaper', 'phone', 'looks', 'design', 'looking', '..then', 'oppo', 'f11', 'pro', 'best', 'phone', 'u']
# ['good', 'phone', 'from', 'oppo', 'nice', 'face', 'unlock', 'good', 'sound', 'best', 'is', 'the', 'notch', 'screen', 'truly', 'awesome', '...', 'great', 'built', 'quality', 'but', 'no', 'fast', 'charging', 'no', '4k', 'recording', 'colours', 'are', 'oversaturated', 'in', 'camera', 'mi', 'note', '5', 'pro', 'have', 'better', 'camera', '.', 'the', 'camera', 'quality', 'is', 'poor', 'compare', 'with', 'samsung', 's7which', 'is', '2016', 'model', 'and', 'oppo', 'f11', 'pro', 'is', '2018', '.', 'i', 'brought', 'is', 'for', 'myself', 'but', 'am', 'giving', 'this', 'phone', 'to', 'my', 'mom', 'coz', 'phone', 'is', 'not', 'for', 'me', 'buy', 'this', 'phone', 'only', 'if', 'you', 'like', 'notch', 'screen', 'in', 'budget', 'phone']
# ['good', 'phone', 'oppo', 'nice', 'face', 'unlock', 'good', 'sound', 'best', 'notch', 'screen', 'truly', 'awesome', '...', 'great', 'built', 'quality', 'fast', 'charging', '4k', 'recording', 'colours', 'oversaturated', 'camera', 'mi', 'note', '5', 'pro', 'better', 'camera', 'camera', 'quality', 'poor', 'compare', 'samsung', 's7which', '2016', 'model', 'oppo', 'f11', 'pro', '2018', 'brought', 'giving', 'phone', 'mom', 'coz', 'phone', 'buy', 'phone', 'like', 'notch', 'screen', 'budget', 'phone']
# ['trust', 'me', 'this', 'phone', 'is', 'well', 'ahead', 'of', 'its', 'time', ',', 'in', '15k', 'you', 'wo', "n't", 'find', '6.5', 'inch', 'display', 'with', 'such', 'clarity', 'and', 'screen', 'to', 'body', 'ratio', 'and', 'beezels', 'are', 'next', 'to', 'non', 'exsisting', '.', 'now', 'its', 'sound', 'quality', 'which', 'is', 'really', 'good', ',', 'i', 'mean', 'via', 'headphone', 'it', 'lack', 'amplification', 'but', 'do', "n't", 'get', 'me', 'wrong', ',', 'at', 'full', 'volume', 'it', "'s", 'loud', 'enough', 'with', 'great', 'bass', 'and', 'clarity', ',', 'very', 'much', 'recommended', 'for', 'those', 'who', 'stays', 'on', 'headphone', 'for', 'long', 'period', '.', 'the', 'best', 'part', 'is', 'its', 'call', 'quality', 'and', 'signal', 'reception', ',', 'its', 'simply', 'outstanding', '.', 'battery', 'is', 'good', 'enough', 'but', 'not', 'for', 'power', 'users', '.', 'overall', 'if', 'you', 'buy', 'this', 'product', ',', 'it', 'will', 'not', 'go', 'out', 'of', 'style', 'for', 'atleast', '3', 'years', 'mainly', 'considering', 'its', 'price', '.']
# ['trust', 'phone', 'well', 'ahead', 'time', ',', '15k', 'wo', "n't", 'find', '6.5', 'inch', 'display', 'clarity', 'screen', 'body', 'ratio', 'beezels', 'next', 'non', 'exsisting', 'sound', 'quality', 'really', 'good', ',', 'mean', 'via', 'headphone', 'lack', 'amplification', "n't", 'get', 'wrong', ',', 'full', 'volume', "'s", 'loud', 'enough', 'great', 'bass', 'clarity', ',', 'much', 'recommended', 'stays', 'headphone', 'long', 'period', 'best', 'part', 'call', 'quality', 'signal', 'reception', ',', 'simply', 'outstanding', 'battery', 'good', 'enough', 'power', 'users', 'overall', 'buy', 'product', ',', 'go', 'style', 'atleast', '3', 'years', 'mainly', 'considering', 'price']
# ['i', 'have', 'moved', 'to', 'this', 'model', 'afr', 'using', 'oneplus', 'one', 'for', 'more', 'than', '3', 'years', '.', 'basically', 'the', 'phone', 'looks', 'good', 'and', 'works', 'decent', '.', 'but', 'the', 'major', 'let', 'down', 'is', 'the', 'camera', '.', 'phone', 'does', "n't", 'have', 'photographic', 'touch', ',', 'it', 'just', 'enhance', 'the', 'picture', 'by', 'the', 'software', 'which', 'makes', 'it', 'un-realistic', '.', 'touch', 'focus', 'does', "n't", 'work', 'well', 'also', 'they', 'have', 'a', 'minimum', 'focal', 'distance', 'for', 'the', 'the', 'camera', 'beyond', 'which', 'it', 'will', 'give', 'a', 'crisp', 'images', ',', 'lesser', 'than', 'that', 'u', 'will', 'end', 'up', 'in', 'getting', 'blurred', 'images', '.', 'there', 'is', 'a', 'difference', 'between', 'bokeh', 'effect', 'and', 'blurred', 'background', 'which', 'wo', "n't", 'satisfy', 'the', 'photography', 'enthusiast', '.']
# ['moved', 'model', 'afr', 'using', 'oneplus', 'one', '3', 'years', 'basically', 'phone', 'looks', 'good', 'works', 'decent', 'major', 'let', 'camera', 'phone', "n't", 'photographic', 'touch', ',', 'enhance', 'picture', 'software', 'makes', 'un-realistic', 'touch', 'focus', "n't", 'work', 'well', 'also', 'minimum', 'focal', 'distance', 'camera', 'beyond', 'give', 'crisp', 'images', ',', 'lesser', 'u', 'end', 'getting', 'blurred', 'images', 'difference', 'bokeh', 'effect', 'blurred', 'background', 'wo', "n't", 'satisfy', 'photography', 'enthusiast']
# ['except', 'camera', 'everything', 'is', 'fine', '.', 'so', 'if', 'u', 'do', "n't", 'look', 'for', 'the', 'mobile', 'for', 'best', 'quality', 'images', 'then', 'go', 'for', 'it', '.', 'its', 'a', 'good', 'deal']
# ['except', 'camera', 'everything', 'fine', 'u', "n't", 'look', 'mobile', 'best', 'quality', 'images', 'go', 'good', 'deal']
# ['the', 'phone', 'packs', 'everything', 'it', 'should', 'for', 'the', 'price', 'range', 'and', 'comes', 'in', 'a', 'package', 'that', 'is', 'more', 'than', 'desirable', '.', 'decent', 'camera', ',', 'great', 'screen', ',', 'good', 'enough', 'battery', 'with', 'a', 'frugal', 'power', 'consumption', '.', 'average', 'usage', 'can', 'easily', 'take', 'you', 'through', 'the', 'day', '.', 'paired', 'with', 'the', 'right', 'kind', 'of', 'earphones', ',', 'this', 'makes', 'for', 'a', 'great', 'device', 'for', 'media', 'consumption', '.', 'and', 'the', 'looks', ',', 'it', 'gives', 'most', 'flagships', 'a', 'run', 'for', 'their', 'money', 'with', 'its', 'gorgeous', 'gradient', 'back', 'panel', 'covered', 'in', 'glass', '.', 'build', 'quality', 'also', 'feels', 'great', 'and', 'does', "n't", 'feel', 'like', 'looks', 'come', 'at', 'the', 'cost', 'of', 'sturdiness', '.', 'glass', 'panels', 'do', 'make', 'it', 'a', 'bit', 'vulnerable', ',', 'but', 'there', 'are', 'crackling', 'of', 'panels', 'as', 'such', '.', 'very', 'solid', 'fit', 'and', 'finish', '.']
# ['phone', 'packs', 'everything', 'price', 'range', 'comes', 'package', 'desirable', 'decent', 'camera', ',', 'great', 'screen', ',', 'good', 'enough', 'battery', 'frugal', 'power', 'consumption', 'average', 'usage', 'easily', 'take', 'day', 'paired', 'right', 'kind', 'earphones', ',', 'makes', 'great', 'device', 'media', 'consumption', 'looks', ',', 'gives', 'flagships', 'run', 'money', 'gorgeous', 'gradient', 'back', 'panel', 'covered', 'glass', 'build', 'quality', 'also', 'feels', 'great', "n't", 'feel', 'like', 'looks', 'come', 'cost', 'sturdiness', 'glass', 'panels', 'make', 'bit', 'vulnerable', ',', 'crackling', 'panels', 'solid', 'fit', 'finish']
# ['poor', 'quality', 'and', 'sound', 'problem', 'and', 'with', 'out', 'charging', 'heat', 'sound', 'effects', 'bad']
# ['poor', 'quality', 'sound', 'problem', 'charging', 'heat', 'sound', 'effects', 'bad']
# ['do', "n't", 'regret', 'at', 'all', 'after', 'purchasing', 'this', 'phone', '.', 'it', "'s", 'perfect', 'in', 'almost', 'all', 'segments', 'considering', 'its', 'mid', 'range', 'segment', '.', 'the', 'best', 'part', 'is', 'battery', 'and', 'performance', 'which', 'is', 'better', 'than', 'any', 'other', 'phone', 'available', 'in', 'same', 'range', '.', 'i', 'have', 'been', 'huawei', 'user', 'since', 'last', '7', 'years', 'and', 'have', "n't", 'faced', 'any', 'issue', 'till', 'now', '.', 'for', 'those', 'who', 'are', 'whining', 'in', 'the', 'name', 'of', 'camera', ',', 'i', 'suggest', 'to', 'go', 'and', 'buy', 'dslr', '.', 'let', 'phones', 'be', 'phones', 'and', 'cameras', 'be', 'cameras', '.']
# ["n't", 'regret', 'purchasing', 'phone', "'s", 'perfect', 'almost', 'segments', 'considering', 'mid', 'range', 'segment', 'best', 'part', 'battery', 'performance', 'better', 'phone', 'available', 'range', 'huawei', 'user', 'since', 'last', '7', 'years', "n't", 'faced', 'issue', 'till', 'whining', 'name', 'camera', ',', 'suggest', 'go', 'buy', 'dslr', 'let', 'phones', 'phones', 'cameras', 'cameras']
# ['excellent', 'product', 'in', 'price', 'range', '...', 'given', 'good', 'tricks', 'in', 'camera', '...', 'forgot', 'any', 'review', '...', 'easy', 'to', 'handle', '...', 'easy', 'to', 'use', '...', 'best', 'ui', '.', 'full', 'entertaining', 'phone', '.', 'there', 'is', 'no', 'issue', 'in', 'mobile', 'only', 'small', 'thing', 'we', 'can', 'say..', 'night', 'shots', 'are', "n't", 'perfect', 'but', 'we', 'can', 'not', 'blame', 'to', 'company', '...', 'with', 'the', 'small', 'amount', 'we', 'can', 'not', 'expect', 'hefty', 'features', '.', 'the', 'camera', 'is', 'awasome', '.', 'overall', 'it', "'s", 'a', 'worthy', 'phone', '.', 'the', 'mobile', 'is', 'not', 'bulky', 'and', 'easy', 'to', 'use', '.', 'recommending', 'some', 'one', 'who', 'is', 'buying', 'xioami', 'phone', '.', 'phone', 'looks', 'premium', 'in', 'hand']
# ['excellent', 'product', 'price', 'range', '...', 'given', 'good', 'tricks', 'camera', '...', 'forgot', 'review', '...', 'easy', 'handle', '...', 'easy', 'use', '...', 'best', 'ui', 'full', 'entertaining', 'phone', 'issue', 'mobile', 'small', 'thing', 'say..', 'night', 'shots', "n't", 'perfect', 'blame', 'company', '...', 'small', 'amount', 'expect', 'hefty', 'features', 'camera', 'awasome', 'overall', "'s", 'worthy', 'phone', 'mobile', 'bulky', 'easy', 'use', 'recommending', 'one', 'buying', 'xioami', 'phone', 'phone', 'looks', 'premium', 'hand']
# ['guys', 'camera', 'quality', 'is', 'too', 'too', 'awesome', '.', 'even', 'in', 'low', 'lighting', 'conditions', 'it', 'is', 'working', 'so', 'much', 'fine', '.', 'video', 'recording', 'in', '60', 'fps', 'is', 'awesomely', 'awesome', '.', 'phone', 'is', 'smooth', 'as', 'butter', '.', 'ekdam', 'raparap', 'chlega', 'without', 'any', 'issues', '.', 'touch', 'is', 'flawless', 'smooth', 'and', 'very', 'sensitive', '.', 'overall', 'best', 'phone', '.']
# ['guys', 'camera', 'quality', 'awesome', 'even', 'low', 'lighting', 'conditions', 'working', 'much', 'fine', 'video', 'recording', '60', 'fps', 'awesomely', 'awesome', 'phone', 'smooth', 'butter', 'ekdam', 'raparap', 'chlega', 'without', 'issues', 'touch', 'flawless', 'smooth', 'sensitive', 'overall', 'best', 'phone']
# ['i', 'like', 'the', 'camera', 'the', 'most', ',', 'both', 'front', 'and', 'back', 'cameras', 'click', 'good', 'quality', 'picture', '.', 'the', 'os', 'is', 'fluid', 'and', 'fast', '.', 'no', 'heating', 'issue', 'noticed', 'so', 'far', ',', 'feels', 'very', 'premium', 'to', 'hold', '.', 'only', 'drawback', 'is', ',', 'out', 'of', '4gb', 'ram', ',', 'less', 'than', '2gb', 'is', 'available', 'to', 'user', '.', 'i', 'do', 'not', 'do', 'any', 'gaming', 'and', 'have', 'limited', 'apps', 'installed', 'still', 'have', 'noticed', 'this', '.', 'ram', 'management', 'could', 'be', 'better', ',', 'also', 'when', 'switching', 'better', 'screens', 'it', 'jitters', 'a', 'little', 'at', 'times', '.']
# ['like', 'camera', ',', 'front', 'back', 'cameras', 'click', 'good', 'quality', 'picture', 'os', 'fluid', 'fast', 'heating', 'issue', 'noticed', 'far', ',', 'feels', 'premium', 'hold', 'drawback', ',', '4gb', 'ram', ',', 'less', '2gb', 'available', 'user', 'gaming', 'limited', 'apps', 'installed', 'still', 'noticed', 'ram', 'management', 'could', 'better', ',', 'also', 'switching', 'better', 'screens', 'jitters', 'little', 'times']
# ['no', 'video', 'call…disappointed', '...', 'phone', 'is', 'very', 'delicate', '.', 'screen', 'broken', 'in', 'just', 'one', 'drop', 'from', 'two', 'feet', 'height']
# ['video', 'call…disappointed', '...', 'phone', 'delicate', 'screen', 'broken', 'one', 'drop', 'two', 'feet', 'height']
# ['looks', 'and', 'design', 'are', 'just', 'marvellous', '.', 'light', '&', 'brightness', 'are', 'also', 'good', '.', 'expected', 'headfone', 'but', 'did', "n't", 'get', '.', 'overall', 'fone', 'is', 'total', 'upto', 'the', 'mark', 'as', 'shown', 'in', 'pic', '.', 'one', 'thing', 'this', 'tym', 'am', 'disappointed', ',', 'otp', 'was', 'deleted', 'by', 'chance', 'nd', 'agent', 'did', 'nt', 'even', 'helped', 'me', ',', 'he', 'declined', 'for', 'delivery', 'and', 'even', 'was', 'not', 'giving', 'cus', 'care', 'no', 'nd', 'solution', '.']
# ['looks', 'design', 'marvellous', 'light', '&', 'brightness', 'also', 'good', 'expected', 'headfone', "n't", 'get', 'overall', 'fone', 'total', 'upto', 'mark', 'shown', 'pic', 'one', 'thing', 'tym', 'disappointed', ',', 'otp', 'deleted', 'chance', 'nd', 'agent', 'nt', 'even', 'helped', ',', 'declined', 'delivery', 'even', 'giving', 'cus', 'care', 'nd', 'solution']
# ['his', 'phone', 'is', 'amazing', 'for', 'the', 'money', '.', 'great', 'for', 'gaming', '.', 'meets', 'all', 'my', 'needs', '.', 'the', 'camera', 'is', 'average', 'in', 'low', 'light', 'but', 'does', 'good', 'in', 'well', 'lit', 'conditions', '.', 'durable', 'as', 'well', '.', 'i', "'ve", 'dropped', 'it', 'countless', 'times', 'with', 'no', 'cover', 'and', 'it', 'has', 'survived', 'with', 'no', 'problem', '.', 'i', "'ve", 'always', 'been', 'a', 'samsung', 'fan', 'boy', 'but', 'not', 'anymore', '.', 'this', 'is', 'way', 'better', 'than', 'any', 'samsung', 'phone', 'in', 'this', 'price', 'range', '.']
# ['phone', 'amazing', 'money', 'great', 'gaming', 'meets', 'needs', 'camera', 'average', 'low', 'light', 'good', 'well', 'lit', 'conditions', 'durable', 'well', "'ve", 'dropped', 'countless', 'times', 'cover', 'survived', 'problem', "'ve", 'always', 'samsung', 'fan', 'boy', 'anymore', 'way', 'better', 'samsung', 'phone', 'price', 'range']
# ['below', 'average', 'picture', 'quality.unable', 'to', 'delete', 'multiple', 'message.vibrating', 'while', 'connect', 'and', 'disconnect', 'the', 'call.not', 'getting', 'good', 'network', 'signal.overall', ',', 'many', 'good', 'options', 'are', 'not', 'included', 'in', 'this', 'phone', '.']
# ['average', 'picture', 'quality.unable', 'delete', 'multiple', 'message.vibrating', 'connect', 'disconnect', 'call.not', 'getting', 'good', 'network', 'signal.overall', ',', 'many', 'good', 'options', 'included', 'phone']
# ['my', 'oppo', 'f11', 'pro', 'display', 'is', 'blurring', 'and', 'i', 'surprise', 'to', 'see', 'the', 'video', 'quality', 'is', 'like', '4000', 'rs', 'cost', 'mobile', '.i', 'am', 'very', 'disappointed', '.']
# ['oppo', 'f11', 'pro', 'display', 'blurring', 'surprise', 'see', 'video', 'quality', 'like', '4000', 'rs', 'cost', 'mobile', '.i', 'disappointed']
# ['excellent', 'build', 'quality..', 'a', 'superior', 'display..', 'very', 'good', 'calling', 'sound..', 'spectacular', 'cameras..', 'lightweight..', 'a', 'good', 'battery..', 'faster', 'than', 'any', 'other', 'phones', 'in', '15k', 'category..', 'what', 'else', 'you', 'need', '?', 'go', 'for', 'it', 'guys..', '!', '!', 'dont', 'think..', '!', '!', 'its', 'a', 'very', 'pocket', 'friendly', 'and', 'rich', 'choice..', '!', '!']
# ['excellent', 'build', 'quality..', 'superior', 'display..', 'good', 'calling', 'sound..', 'spectacular', 'cameras..', 'lightweight..', 'good', 'battery..', 'faster', 'phones', '15k', 'category..', 'else', 'need', '?', 'go', 'guys..', '!', '!', 'dont', 'think..', '!', '!', 'pocket', 'friendly', 'rich', 'choice..', '!', '!']
# ['honor', ',', ',', 'you', 'made', 'a', 'great', 'deal..']
# ['honor', ',', ',', 'made', 'great', 'deal..']
# ['t', 'is', 'the', 'one', 'of', 'the', 'best', 'choice', 'from', 'its', 'segment', 'as', 'its', 'a', 'oppo', 'you', 'wo', "n't", 'be', 'dissapointed', 'with', 'its', 'finger', 'print', ',', 'screen', 'quality', 'and', 'camera', ',', 'built', 'quality', ',', 'only', 'probs', 'only', 'some', 'will', 'find', 'if', 'you', 'do', "n't", 'use', 'to', 'do', 'video', 'recording', 'as', 'it', 'does', "n't", 'have', 'an', 'eis', 'or', 'ois', 'other', 'than', 'that', 'nothing', 'to', 'worry', 'about', 'processor', ',', 'battery', ',', 'built', 'quality', 'simply', 'go', 'for', 'it', 'the', 'kirin', '710', 'will', 'do', 'anything', 'for', 'you', 'it', 'has', 'also', 'made', 'a', 'score', 'on', 'one', 'of', 'the', 'best', 'smartphone']
# ['one', 'best', 'choice', 'segment', 'oppo', 'wo', "n't", 'dissapointed', 'finger', 'print', ',', 'screen', 'quality', 'camera', ',', 'built', 'quality', ',', 'probs', 'find', "n't", 'use', 'video', 'recording', "n't", 'eis', 'ois', 'nothing', 'worry', 'processor', ',', 'battery', ',', 'built', 'quality', 'simply', 'go', 'kirin', '710', 'anything', 'also', 'made', 'score', 'one', 'best', 'smartphone']
# ['very', 'worst', 'mobile', 'in', 'photos.', ',', 'totally', 'waste', 'oppo', 'f11', 'pro', ',', 'even', 'one', 'picture', 'also', 'clarity', '.', 'look', 'like', '5mega', 'pixel', 'picture', ',', 'after', 'taken', 'picture', 'if', 'you', 'zoom', 'slightly', 'image', 'will', 'break', 'full', ',', 'zero', 'percentage', 'in', 'clarity', ',', 'if', 'you', '10', 'pic', ',', 'at', 'least', 'one', 'or', 'two', 'only', 'good', ',', 'if', 'you', 'flash', 'light', 'it', 'will', 'blink', 'but', 'not', 'reflect', 'in', 'picture', ',']
# ['worst', 'mobile', 'photos.', ',', 'totally', 'waste', 'oppo', 'f11', 'pro', ',', 'even', 'one', 'picture', 'also', 'clarity', 'look', 'like', '5mega', 'pixel', 'picture', ',', 'taken', 'picture', 'zoom', 'slightly', 'image', 'break', 'full', ',', 'zero', 'percentage', 'clarity', ',', '10', 'pic', ',', 'least', 'one', 'two', 'good', ',', 'flash', 'light', 'blink', 'reflect', 'picture', ',']
# ['the', 'battery', 'life', 'phone', 'is', 'awesome', '.', 'the', 'camera', 'on', 'the', 'other', 'hand', 'beautiful', 'however', 'there', 'are', 'some', 'picture', 'quality', 'issues', '.', 'but', 'works', 'fine', '.', 'the', 'selfies', 'are', 'good', '.', 'fingerprint', 'and', 'face', 'unlock', 'features', 'are', 'very', 'fine', '.', 'the', 'video', 'quality', 'is', 'very', 'fine', 'to', 'watch', 'not', 'to', 'shoot', '.', 'the', 'speed', 'is', 'incredible', 'and', 'the', 'display', 'is', 'very', 'fine', '.', 'however', 'the', 'sound', 'quality', 'is', 'above', 'average', 'and', 'the', 'loudness', 'seems', 'be', 'above', 'average', 'too', '.', 'hopefully', ',', 'the', 'software', 'update', 'can', 'fix', 'camera', '.', 'overall', 'this', 'is', 'very', 'good', 'phone', 'and', 'has', 'premium', 'look', '.']
# ['battery', 'life', 'phone', 'awesome', 'camera', 'hand', 'beautiful', 'however', 'picture', 'quality', 'issues', 'works', 'fine', 'selfies', 'good', 'fingerprint', 'face', 'unlock', 'features', 'fine', 'video', 'quality', 'fine', 'watch', 'shoot', 'speed', 'incredible', 'display', 'fine', 'however', 'sound', 'quality', 'average', 'loudness', 'seems', 'average', 'hopefully', ',', 'software', 'update', 'fix', 'camera', 'overall', 'good', 'phone', 'premium', 'look']
# ['i', "'ve", 'purchased', 'this', 'phone', 'for', 'my', 'mom', '.', 'the', 'phone', 'is', 'excellent', '.', 'it', "'s", 'physical', 'appearance', 'is', 'very', 'appealing', 'and', 'makes', 'it', 'look', 'like', 'a', 'premium', 'phone', '.', 'the', 'performance', 'in', 'terms', 'of', 'speed', 'is', 'very', 'good', 'and', 'also', 'because', 'of', 'honor', "'s", 'gpu', 'turbo', ',', 'gaming', 'is', 'a', 'breeze', '.', 'the', 'battery', 'life', 'is', 'good', 'but', 'it', 'misses', 'out', 'on', 'quickcharge', '.', 'the', 'speaker', 'is', 'average', 'but', 'headphone', 'music', 'quality', 'is', 'good', '.', 'calls', 'are', 'also', 'good', '.', 'overall', 'i', 'would', 'recommend', 'this', 'mobile', '.']
# ["'ve", 'purchased', 'phone', 'mom', 'phone', 'excellent', "'s", 'physical', 'appearance', 'appealing', 'makes', 'look', 'like', 'premium', 'phone', 'performance', 'terms', 'speed', 'good', 'also', 'honor', "'s", 'gpu', 'turbo', ',', 'gaming', 'breeze', 'battery', 'life', 'good', 'misses', 'quickcharge', 'speaker', 'average', 'headphone', 'music', 'quality', 'good', 'calls', 'also', 'good', 'overall', 'would', 'recommend', 'mobile']
# ['sound', 'quality', 'is', 'really', 'bad', '...', 'for', 'this', 'price', 'good', 'speakers', 'are', 'must..', 'i', 'thought', 'i', 'would', 'b', 'deal', 'braker', 'against', 'realme2pro', 'but', 'realme', 'speakers', 'r', 'really', 'amazing..', 'if', 'i', 'use', 'earphone', 'i', 'ca', "n't", 'even', 'here', 'properly', 'at', 'full', 'volume..', 'for', 'this', 'reason', 'i', 'have', 'already', 'exchanged', 'once', 'but', 'got', 'the', 'same', 'result', 'which', 'is', 'very', 'disappointing..', 'other', 'than', 'speakers', 'i', 'just', 'loved', 'd', 'phone..camera', ',', 'build', 'quality', ',', 'look', ',', 'everything..', 'ido', "n't", 'want', '4k', 'recording', 'n', 'other', 'things..', 'but', 'a', 'good', 'speaker', 'is', 'a', 'must..', '..', 'please', 'do', 'correct', 'it', 'by', 'upgradation..', 'i', 'do', "n't", 'want', 'to', 'return', 'it', 'just', 'for', 'speakers..', 'it', "'s", 'a', 'request', '.']
# ['sound', 'quality', 'really', 'bad', '...', 'price', 'good', 'speakers', 'must..', 'thought', 'would', 'b', 'deal', 'braker', 'realme2pro', 'realme', 'speakers', 'r', 'really', 'amazing..', 'use', 'earphone', 'ca', "n't", 'even', 'properly', 'full', 'volume..', 'reason', 'already', 'exchanged', 'got', 'result', 'disappointing..', 'speakers', 'loved', 'phone..camera', ',', 'build', 'quality', ',', 'look', ',', 'everything..', 'ido', "n't", 'want', '4k', 'recording', 'n', 'things..', 'good', 'speaker', 'must..', '..', 'please', 'correct', 'upgradation..', "n't", 'want', 'return', 'speakers..', "'s", 'request']
# ['its', 'really', 'awesome', 'trending', 'phone', 'under', 'this', 'price', 'segment', 'so', 'if', 'yu', 'ar', 'thinking', 'about', 'it', 'buy', 'it', ',', 'there', 'is', 'no', 'issue', 'i', 'had', 'compared', 'with', 'real', 'me', '2', 'pro', 'but', 'this', 'was', 'always', 'winner', '...', '..', '?', '?', 'so', 'yu', 'can', 'buy', 'awesome', 'with', 'amazing', 'camera', '.', 'do', "n't", 'go', 'for', 'realme', '2', 'pro', 'its', 'plastic', 'body', 'nd', 'camera', '?', '?', 'is', 'not', 'good', '.']
# ['really', 'awesome', 'trending', 'phone', 'price', 'segment', 'yu', 'ar', 'thinking', 'buy', ',', 'issue', 'compared', 'real', '2', 'pro', 'always', 'winner', '...', '..', '?', '?', 'yu', 'buy', 'awesome', 'amazing', 'camera', "n't", 'go', 'realme', '2', 'pro', 'plastic', 'body', 'nd', 'camera', '?', '?', 'good']
# ['i', 'have', 'purchased', 'this', 'mobile', 'on', 'feb', '4th', '2019.', 'it', 'worked', 'fine', 'for', 'two', 'weeks', ',', 'but', 'suddenly', 'after', 'that', ',', 'one', 'day', 'the', 'os', 'got', 'crashed', 'while', 'the', 'mobile', 'is', 'kept', 'for', 'charging', '.', 'i', 'tried', 'many', 'ways', 'to', 'resolve', ',', 'but', 'finally', 'after', 'sometime', 'i', 'tried', 'restarting', 'by', 'pressing', 'the', 'power', 'button', '&', 'volume', 'button', 'simultaneously', ',', 'exactly', 'after', '10', 'minutes', ',', 'the', 'mobile', 'restarted', 'and', 'started', 'working', 'normally', '.', 'i', 'do', "n't", 'know', 'the', 'cause', 'of', 'this', 'crash', ',', 'since', 'i', 'have', "n't", 'installed', 'any', 'big', 'apps', 'neither', 'any', 'game', 'in', 'my', 'mobile', '.', 'but', 'seriously', 'oppo', 'should', 'look', 'into', 'these', 'sudden', 'crashes', 'and', 'display', 'offs', '.', 'apart', 'from', 'this', 'software', 'issue', ',', 'the', 'phone', 'is', 'perfect', 'under', 'this', 'budget', '.', 'hope', 'i', 'do', "n't", 'see', 'the', 'same', 'issue', 'again..']
# ['purchased', 'mobile', 'feb', '4th', '2019.', 'worked', 'fine', 'two', 'weeks', ',', 'suddenly', ',', 'one', 'day', 'os', 'got', 'crashed', 'mobile', 'kept', 'charging', 'tried', 'many', 'ways', 'resolve', ',', 'finally', 'sometime', 'tried', 'restarting', 'pressing', 'power', 'button', '&', 'volume', 'button', 'simultaneously', ',', 'exactly', '10', 'minutes', ',', 'mobile', 'restarted', 'started', 'working', 'normally', "n't", 'know', 'cause', 'crash', ',', 'since', "n't", 'installed', 'big', 'apps', 'neither', 'game', 'mobile', 'seriously', 'oppo', 'look', 'sudden', 'crashes', 'display', 'offs', 'apart', 'software', 'issue', ',', 'phone', 'perfect', 'budget', 'hope', "n't", 'see', 'issue', 'again..']
# ['the', 'phone', 'build', 'quality', 'is', 'good', 'and', 'looks', 'wise', 'its', 'best', 'in', 'the', 'class', '.', 'the', 'worst', 'part', 'of', 'this', 'is', 'its', 'camera', '.', 'i', 'mean', 'how', 'can', 'you', 'say', 'that', 'its', 'camera', 'is', 'of', '20', 'mp', 'and', 'that', 'is', 'also', 'with', 'ai', '.', 'the', 'photos', 'clicked', 'by', 'rear', 'camera', 'seems', 'to', 'be', 'click', 'by', 'a', '2mp', 'camera', '.', 'earlier', 'i', 'was', 'using', 'mi', 'a1', 'and', 'its', 'camera', 'is', 'par', 'from', 'oppo', 'f11', 'pro', '.', 'i', 'think', 'oppo', 'can', 'fix', 'this', 'by', 'update', '.', 'until', 'then', 'i', 'will', 'suggest', 'you', 'to', 'buy', 'some', 'other', 'phone', 'like', 'realme', '2', 'pro', 'or', 'mi', 'note', '5', 'pro', 'if', 'camera', 'is', 'your', 'first', 'priority', '.']
# ['phone', 'build', 'quality', 'good', 'looks', 'wise', 'best', 'class', 'worst', 'part', 'camera', 'mean', 'say', 'camera', '20', 'mp', 'also', 'ai', 'photos', 'clicked', 'rear', 'camera', 'seems', 'click', '2mp', 'camera', 'earlier', 'using', 'mi', 'a1', 'camera', 'par', 'oppo', 'f11', 'pro', 'think', 'oppo', 'fix', 'update', 'suggest', 'buy', 'phone', 'like', 'realme', '2', 'pro', 'mi', 'note', '5', 'pro', 'camera', 'first', 'priority']
# ['the', 'camera', 'is', 'too', 'good', 'when', 'the', 'ai', 'is', 'turned', 'on', 'but', 'only', 'in', 'the', 'natural', 'light', 'i.e', 'outdoor', '.', 'the', 'pictures', 'taken', 'under', 'artificial', 'lighting', 'are', 'very', 'poor', ',', 'the', 'updates', 'are', 'coming', 'in', 'this', 'oppo', 'device', '.', 'the', 'glass', 'back', 'is', 'pretty', 'awesome', 'with', 'an', 'expensive', 'feeling', 'but', 'the', 'problem', 'is', 'the', 'fingerprint', 'that', 'remains', 'on', 'the', 'glass', 'as', 'we', 'take', 'the', 'phone', 'in', 'hand', '.', 'fingerprint', 'sensor', 'is', 'fast', 'and', 'battery', 'life', 'is', '24', 'hr', 'for', 'me', 'as', 'i', 'play', 'pubg', 'for', 'more', 'than', '3', 'hrx', 'with', 'a', 'great', 'experience', 'shared', 'by', 'the', 'processor', '.']
# ['camera', 'good', 'ai', 'turned', 'natural', 'light', 'i.e', 'outdoor', 'pictures', 'taken', 'artificial', 'lighting', 'poor', ',', 'updates', 'coming', 'oppo', 'device', 'glass', 'back', 'pretty', 'awesome', 'expensive', 'feeling', 'problem', 'fingerprint', 'remains', 'glass', 'take', 'phone', 'hand', 'fingerprint', 'sensor', 'fast', 'battery', 'life', '24', 'hr', 'play', 'pubg', '3', 'hrx', 'great', 'experience', 'shared', 'processor']
# ['best', 'phone', 'till', 'date', 'within', 'this', 'price', 'range', '.', 'amazing', 'camera', 'and', 'display', 'quality', '.', 'you', 'cam', 'simply', 'play', 'with', 'the', 'camera', '.', 'ai', 'mode', 'will', 'help', 'you', 'to', 'identify', 'the', 'picture', 'mode', 'and', 'will', 'give', 'you', 'a', 'decent', 'photo', '.', 'photo', 'processor', 'adds', 'a', 'bit', 'more', 'color', 'which', 'is', 'not', 'that', 'bad', '.', 'battery', 'backup', 'is', 'good', 'but', 'we', 'expected', 'a', 'bit', 'better', '.', 'but', 'you', 'can', 'easily', 'depend', 'on', 'it', '.', 'once', 'the', 'device', 'is', 'fully', 'charged', 'it', 'can', 'stay', 'upto', '1day', 'with', 'all', 'day', 'activity', '.', 'sound', 'quality', 'is', 'balanced', 'both', 'on', 'handphone', 'and', 'device', 'speaker', '.', 'finest', 'combination', 'of', 'bass', 'and', 'treeble', '.', 'built', 'quality', 'is', 'too', 'good', 'but', 'its', 'always', 'good', 'to', 'use', 'the', 'in', 'box', 'case', 'to', 'protect', 'the', 'back', 'as', 'it', 'is', 'made', 'of', 'glass', '.']
# ['best', 'phone', 'till', 'date', 'within', 'price', 'range', 'amazing', 'camera', 'display', 'quality', 'cam', 'simply', 'play', 'camera', 'ai', 'mode', 'help', 'identify', 'picture', 'mode', 'give', 'decent', 'photo', 'photo', 'processor', 'adds', 'bit', 'color', 'bad', 'battery', 'backup', 'good', 'expected', 'bit', 'better', 'easily', 'depend', 'device', 'fully', 'charged', 'stay', 'upto', '1day', 'day', 'activity', 'sound', 'quality', 'balanced', 'handphone', 'device', 'speaker', 'finest', 'combination', 'bass', 'treeble', 'built', 'quality', 'good', 'always', 'good', 'use', 'box', 'case', 'protect', 'back', 'made', 'glass']
# ['its', 'was', 'great', 'experience', 'from', 'last', '2', 'months', 'use', 'but', 'only', 'the', 'issue', 'with', 'online', 'website', 'zoomed', 'and', 'cant', 'reduce', 'size', 'that', 'why', 'many', 'pages', 'words', '&', 'content', 'cut', 'off', 'like', 'online', 'bank', 'statement', 'cant', 'see', '100', '%', '.', 'i', 'hope', 'its', 'will', 'be', 'correct', 'in', 'next', 'update', '.', 'other', 'wise', 'batter', 'is', 'best', '&', 'last', 'lasting', 'than', 'my', 'previous', 'mi', 'phones', '.', 'picture', 'clearity', 'is', 'best', 'in', 'class', '.']
# ['great', 'experience', 'last', '2', 'months', 'use', 'issue', 'online', 'website', 'zoomed', 'cant', 'reduce', 'size', 'many', 'pages', 'words', '&', 'content', 'cut', 'like', 'online', 'bank', 'statement', 'cant', 'see', '100', '%', 'hope', 'correct', 'next', 'update', 'wise', 'batter', 'best', '&', 'last', 'lasting', 'previous', 'mi', 'phones', 'picture', 'clearity', 'best', 'class']
# ...
# ['to', 'be', 'frank', '...', 'one', 'can', 'go', 'for', 'this', 'product..', 'for', 'sure', 'because', 'i', 'hope', 'that', 'the', 'rear', 'camera', 'issue', 'will', 'be', 'solved', 'immediately..']
# ['frank', '...', 'one', 'go', 'product..', 'sure', 'hope', 'rear', 'camera', 'issue', 'solved', 'immediately..']
# ['looks', 'like', 'so', 'much', 'close', 'to', 'oneplus', '6', 'with', 'really', 'small', 'chin', 'and', 'notch', ',', 'sound', 'quality', 'is', 'very', 'good']
# ['looks', 'like', 'much', 'close', 'oneplus', '6', 'really', 'small', 'chin', 'notch', ',', 'sound', 'quality', 'good']
# ['good', 'camera', 'quality', 'better', 'than', 'realme', '2', 'pro', ',', 'motorola', 'power', 'one', ',']
# ['good', 'camera', 'quality', 'better', 'realme', '2', 'pro', ',', 'motorola', 'power', 'one', ',']
# ['battery', 'mm', 'i', 'would', 'say', 'lasts', '1', 'day']
# ['battery', 'mm', 'would', 'say', 'lasts', '1', 'day']
# ['awesome', 'mobile', ',', 'processor', 'is', 'far', 'better', 'than', 'sdm660', ',', 'camera', 'is', 'totally', 'outstanding', ',', 'awesome', 'pics', ',', 'display', 'is', 'good', 'though', 'it', 'has', 'big', 'screen', ',', 'battery', 'is', 'good', 'capable', 'of', 'all', 'day', 'long', 'enough', 'when', 'u', 'will', 'play', 'pubg', ',', 'if', 'fast', 'charger', 'supported', 'it', 'will', 'best', ',', 'but', 'good', 'as', 'it', 'charge', 'fast', 'without', 'fast', 'charging', 'takes', 'normally', '2', 'and', '1/2', 'hour']
# ['awesome', 'mobile', ',', 'processor', 'far', 'better', 'sdm660', ',', 'camera', 'totally', 'outstanding', ',', 'awesome', 'pics', ',', 'display', 'good', 'though', 'big', 'screen', ',', 'battery', 'good', 'capable', 'day', 'long', 'enough', 'u', 'play', 'pubg', ',', 'fast', 'charger', 'supported', 'best', ',', 'good', 'charge', 'fast', 'without', 'fast', 'charging', 'takes', 'normally', '2', '1/2', 'hour']
# ['everything', 'thing', 'is', 'ok', 'but', 'very', 'very', 'poor', 'camera', 'during', 'low', 'light', 'condition']
# ['everything', 'thing', 'ok', 'poor', 'camera', 'low', 'light', 'condition']
# ['writing', 'this', 'review', 'after', '2', 'months', 'of', 'usage', '.', 'the', 'outer', 'look', 'is', 'awesome', ',', 'delivered', 'on', 'date', ',', 'camera', 'quality', 'is', 'fabulous', ',', 'loudspeaker', 'could', 'be', 'better', '.', 'it', 'works', 'like', 'a', 'gem', '.', 'the', 'only', 'issue', 'i', 'found', 'was', 'some', 'sort', 'of', 'heating', 'issues', 'when', 'you', 'play', 'a', 'game', '.']
# ['writing', 'review', '2', 'months', 'usage', 'outer', 'look', 'awesome', ',', 'delivered', 'date', ',', 'camera', 'quality', 'fabulous', ',', 'loudspeaker', 'could', 'better', 'works', 'like', 'gem', 'issue', 'found', 'sort', 'heating', 'issues', 'play', 'game']
# ['phone', 'is', 'good', 'but', 'the', 'problem', 'is', 'with', 'its', 'back', '...', 'it', 'has', 'a', 'glass', 'blackp', 'which', 'is', 'very', 'slippery', '...', 'and', 'also', 'the', 'dark', 'strip', 'running', 'on', 'its', 'logo', 'and', 'camera', 'lens', 'is', 'not', 'that', 'much', 'visible', 'to', 'distinguish', 'and', 'the', 'front', 'display', 'is', 'little', 'bigger', 'in', 'length', 'and', 'shorter', 'in', 'width', 'which', 'makes', 'it', 'look', 'like', 'a', 'chocolate', 'bar']
# ['phone', 'good', 'problem', 'back', '...', 'glass', 'blackp', 'slippery', '...', 'also', 'dark', 'strip', 'running', 'logo', 'camera', 'lens', 'much', 'visible', 'distinguish', 'front', 'display', 'little', 'bigger', 'length', 'shorter', 'width', 'makes', 'look', 'like', 'chocolate', 'bar']
# ['this', 'phone', 'worth', 'the', 'money', ',', '.excellent', 'build', 'quality.very', 'good', 'battery', 'life', ',', 'network', 'speed', ',', 'faster', 'charging', '(', 'micro', 'usb', ')', ',', 'good', 'perfomance', ',', 'nice', 'ui.the', 'only', 'con', 'i', 'have', 'noticed', 'is', 'ai', 'mode', 'sometimes', 'little', 'over', 'saturate', 'colurs..hope', 'this', 'will', 'be', 'corrected', 'thru', 'nxt', 'update..overall', 'a', 'power', 'packed', 'perfomance', 'phone', 'in', 'mid', 'range..go', 'for', 'it']
# ['phone', 'worth', 'money', ',', '.excellent', 'build', 'quality.very', 'good', 'battery', 'life', ',', 'network', 'speed', ',', 'faster', 'charging', '(', 'micro', 'usb', ')', ',', 'good', 'perfomance', ',', 'nice', 'ui.the', 'con', 'noticed', 'ai', 'mode', 'sometimes', 'little', 'saturate', 'colurs..hope', 'corrected', 'thru', 'nxt', 'update..overall', 'power', 'packed', 'perfomance', 'phone', 'mid', 'range..go']
# ['battery', 'is', 'good', ',', 'selfie', 'camera', 'is', 'also', 'good', 'but', 'rear', 'camera', 'is', 'poor', 'in', 'low', 'light', 'conditions', 'rear', 'camera', 'can', 'be', 'only', 'use', 'for', 'capturing', 'near', 'images', 'up', 'to', '30cm', 'not', 'more', 'than', 'that', 'rear', 'camera', 'only', 'gives', 'good', 'images', 'in', 'outside', 'conditions', ',', 'night', 'mode', 'is', 'also', 'very', 'good', '.']
# ['battery', 'good', ',', 'selfie', 'camera', 'also', 'good', 'rear', 'camera', 'poor', 'low', 'light', 'conditions', 'rear', 'camera', 'use', 'capturing', 'near', 'images', '30cm', 'rear', 'camera', 'gives', 'good', 'images', 'outside', 'conditions', ',', 'night', 'mode', 'also', 'good']
# ['one', 'word', 'just', 'awesome', 'what', 'a', 'stylish', 'phone', 'you', 'could', "n't", 'ask', 'for', 'better', 'in', 'this', 'price', 'segment', 'with', 'very', 'decent', 'camera', 'quality', 'for', 'night', 'and', 'outdoor', 'condition', '...', 'kirin', '710', 'does', 'a', 'great', 'job', 'better', 'than', 'snapdragon', '660', ',', 'totally', 'loved', 'it', '.']
# ['one', 'word', 'awesome', 'stylish', 'phone', 'could', "n't", 'ask', 'better', 'price', 'segment', 'decent', 'camera', 'quality', 'night', 'outdoor', 'condition', '...', 'kirin', '710', 'great', 'job', 'better', 'snapdragon', '660', ',', 'totally', 'loved']
# ['this', 'phone', 'is', 'awesome', ',', 'the', 'camera', 'of', 'this', 'phone', 'is', 'fabulous', ',', 'i', 'post', 'a', 'night', 'time', 'picture', ',', 'that', 'picture', 'quality', 'say', 'all', 'thing', 'about', 'the', 'camera', ',', 'looks', 'of', 'this', 'phone', 'is', 'very', 'good', ',', 'beattry', 'backup', 'also', 'good', ',', 'in', 'this', 'phone', 'i', 'did', 'not', 'found', 'any', 'type', 'of', 'lacking', 'even', 'when', 'i', 'play', 'a', 'heavy', 'game', '.', 'after', 'baught', 'this', 'i', 'must', 'say', 'i', 'am', 'fully', 'satisfied', 'with', 'this', 'budget', 'phone', '.']
# ['phone', 'awesome', ',', 'camera', 'phone', 'fabulous', ',', 'post', 'night', 'time', 'picture', ',', 'picture', 'quality', 'say', 'thing', 'camera', ',', 'looks', 'phone', 'good', ',', 'beattry', 'backup', 'also', 'good', ',', 'phone', 'found', 'type', 'lacking', 'even', 'play', 'heavy', 'game', 'baught', 'must', 'say', 'fully', 'satisfied', 'budget', 'phone']
# ['battery', 'is', 'worst..', 'battery', 'discharged', 'quickly', 'even', 'in', 'power', 'saving', 'mode', '...', 'other', 'features', 'are', 'good', 'except', 'battery', 'performance', 'is', 'weak', '...']
# ['battery', 'worst..', 'battery', 'discharged', 'quickly', 'even', 'power', 'saving', 'mode', '...', 'features', 'good', 'except', 'battery', 'performance', 'weak', '...']
# ['it', 'is', 'an', 'awesome', 'phone', 'considering', 'the', 'price', '...', '...', 'amazing', 'build', 'quality', ',', 'awesome', 'looks', ',', 'great', 'battery', 'life', ',', 'nice', 'soc', '(', 'kirin', '710', ')', ',', 'good', 'camera', '(', 'but', 'need', 'a', 'software', 'update', 'to', 'make', 'the', 'front', 'portrait', 'better', 'and', 'to', 'make', 'the', 'colour', 'bit', 'more', 'natural', ')', '...', '.', 'overall', 'a', 'great', 'value', 'for', 'money', 'phone', '...', '...', '.', '**hope', 'oppo', 'will', 'push', 'a', 'software', 'update', 'to', 'make', 'it', 'even', 'better**']
# ['awesome', 'phone', 'considering', 'price', '...', '...', 'amazing', 'build', 'quality', ',', 'awesome', 'looks', ',', 'great', 'battery', 'life', ',', 'nice', 'soc', '(', 'kirin', '710', ')', ',', 'good', 'camera', '(', 'need', 'software', 'update', 'make', 'front', 'portrait', 'better', 'make', 'colour', 'bit', 'natural', ')', '...', 'overall', 'great', 'value', 'money', 'phone', '...', '...', '**hope', 'oppo', 'push', 'software', 'update', 'make', 'even', 'better**']
# ['it', '’', 's', 'awesome', '...', 'got', 'in', '2days', 'after', 'booking..', 'nice', 'phone', 'with', 'good', 'camera', 'quality..', 'super', 'fast..', 'no', 'heating', 'issues..', 'battery', 'losts', '1day..', 'outlook', 'and', 'design', 'is', 'excellent', '...', 'value', 'for', 'money..']
# ['’', 'awesome', '...', 'got', '2days', 'booking..', 'nice', 'phone', 'good', 'camera', 'quality..', 'super', 'fast..', 'heating', 'issues..', 'battery', 'losts', '1day..', 'outlook', 'design', 'excellent', '...', 'value', 'money..']
# ['this', 'phone', 'is', 'the', 'beast', '.']
# ['phone', 'beast']
# ['camera', 'is', 'poor', '...', 'depth', 'sensor', 'camera', 'is', 'so', 'confuse', 'about', 'the', 'depth', 'sensing', '...', '.picture', 'colour', 'are', 'over', 'saturated', '(', 'means', 'pink', 'becomes', 'red', 'light', 'green', 'become', 'dark', 'green', '...', 'and', 'so', 'on', ')', 'not', 'natural', 'colour']
# ['camera', 'poor', '...', 'depth', 'sensor', 'camera', 'confuse', 'depth', 'sensing', '...', '.picture', 'colour', 'saturated', '(', 'means', 'pink', 'becomes', 'red', 'light', 'green', 'become', 'dark', 'green', '...', ')', 'natural', 'colour']
# ['it', 'is', 'a', 'very', 'good', 'handset', 'at', 'this', 'price', 'point', '.', 'superb', 'smooth', 'performance.it', 'has', 'a', 'good', 'processor.but', 'it', 'should', 'have', 'electronic', 'stabilization', 'in', 'camera', 'performance', '.', 'we', 'can', 'easily', 'expect', 'this', 'feature', 'at', 'this', 'price', 'point', '.', 'and', 'please', 'make', 'the', 'red', 'colour', 'available', 'for', 'the', '6', 'gb', '64', 'gb', 'varriant', '.']
# ['good', 'handset', 'price', 'point', 'superb', 'smooth', 'performance.it', 'good', 'processor.but', 'electronic', 'stabilization', 'camera', 'performance', 'easily', 'expect', 'feature', 'price', 'point', 'please', 'make', 'red', 'colour', 'available', '6', 'gb', '64', 'gb', 'varriant']
# ['received', 'prepaid', 'order', 'in', '11days', 'after', 'non', 'stop', 'follow', 'up', '.', 'most', 'pathetic', 'experience', '.']
# ['received', 'prepaid', 'order', '11days', 'non', 'stop', 'follow', 'pathetic', 'experience']
# ['rest', 'mobile', 'is', 'good', 'in', 'this', 'price', '.', 'camera', '&', 'speaker', 'needs', 'some', 'serious', 'improvement', '.']
# ['rest', 'mobile', 'good', 'price', 'camera', '&', 'speaker', 'needs', 'serious', 'improvement']
# ['the', 'picture', 'quality', 'is', 'better', 'then', 'all', 'this', 'range', 'phone', 'only', 'if', 'you', 'know', 'about', 'pro', 'mode', '(', 'manual', 'mode', ')', 'sound', 'quality', 'is', 'amazing', '.', '1', 'day', 'long', 'battery', 'life', '.', 'do', "n't", 'play', 'pub', 'on', 'it', 'cos', 'it', 'is', '710', 'with', 'mali', '51.', 'it', 'couse', 'a', 'minor', 'damage', 'on', 'your', 'processor']
# ['picture', 'quality', 'better', 'range', 'phone', 'know', 'pro', 'mode', '(', 'manual', 'mode', ')', 'sound', 'quality', 'amazing', '1', 'day', 'long', 'battery', 'life', "n't", 'play', 'pub', 'cos', '710', 'mali', '51.', 'couse', 'minor', 'damage', 'processor']
# ['it', "'s", 'display', 'is', 'effecting', 'my', 'eyes', 'its', 'not', 'like', 'samsung', 'display', '.', 'so', 'do', "n't", 'buy', 'it']
# ["'s", 'display', 'effecting', 'eyes', 'like', 'samsung', 'display', "n't", 'buy']
# ['features', 'are', 'really', 'very', 'good', 'but', 'the', 'battery', 'life', 'should', 'have', 'been', 'more', '...', 'by', 'multi-tasking', 'the', 'back', 'gets', 'a', 'little', 'bit', 'hot', 'but', 'then', 'also', 'it', 'cools', 'down', 'afterwards', '...', 'else', ',', 'it', 'is', 'a', 'nice', 'model', 'but', 'little', 'bit', 'disappointed', 'with', 'the', 'battery', 'life', '...', 'camera', 'is', 'also', 'very', 'good', 'especially', 'the', 'ai', '?', '?', 'overall', 'its', 'worth', 'for', 'the', 'price', '.']
# ['features', 'really', 'good', 'battery', 'life', '...', 'multi-tasking', 'back', 'gets', 'little', 'bit', 'hot', 'also', 'cools', 'afterwards', '...', 'else', ',', 'nice', 'model', 'little', 'bit', 'disappointed', 'battery', 'life', '...', 'camera', 'also', 'good', 'especially', 'ai', '?', '?', 'overall', 'worth', 'price']
# ['great', 'product', ',', 'its', 'picture', 'quality', 'is', 'too', 'good', ',', 'sound', 'is', 'awesome', ',', 'and', 'battery', 'work', 'full', 'day', ',', 'the', 'smartphone', 'is', 'easy', 'to', 'use', ',', 'has', 'great', 'look', ',', 'fingerprint', 'sensor', 'works', 'quite', 'wellwell', ',', 'happy', 'with', 'the', 'product']
# ['great', 'product', ',', 'picture', 'quality', 'good', ',', 'sound', 'awesome', ',', 'battery', 'work', 'full', 'day', ',', 'smartphone', 'easy', 'use', ',', 'great', 'look', ',', 'fingerprint', 'sensor', 'works', 'quite', 'wellwell', ',', 'happy', 'product']
# ['overall', 'this', 'is', 'nice', 'product.good', 'in', 'camera', 'sensing', 'and', 'fingerprint.bt', 'as', 'compared', 'to', 'redmi', 'this', 'is', 'better', 'product', 'only', 'difference', 'is', 'in', 'processor.this', 'product', 'have', 'kirin', 'processor', 'so', 'it', 'is', 'not', 'good', 'as', 'compared', 'to', 'redo', 'n', 'realme', 'and', 'it', "'s", 'battery', 'backup', 'not', 'so', 'longer.only', 'these', 'two', 'things', 'are', 'not', 'good', 'bt', 'overall', 'it', 'is', 'excellent', 'product', '.']
# ['overall', 'nice', 'product.good', 'camera', 'sensing', 'fingerprint.bt', 'compared', 'redmi', 'better', 'product', 'difference', 'processor.this', 'product', 'kirin', 'processor', 'good', 'compared', 'redo', 'n', 'realme', "'s", 'battery', 'backup', 'longer.only', 'two', 'things', 'good', 'bt', 'overall', 'excellent', 'product']
# ['right', 'choice', 'for', 'the', 'money', 'i', 'spent', '.', 'happy', 'with', 'it', 'really..', 'waited', 'a', 'long', 'to', 'buy', 'a', 'mobile', ',', 'loads', 'of', 'options', 'in', 'this', 'price', 'range', ',', 'select', 'this', 'and', 'my', 'choice', 'dint', 'disappoint', 'me', '...', 'camera', ',', 'battery', 'back', 'up', ',', 'fingerprint', 'and', 'face', 'recognition', ',', 'everything', 'about', 'this', 'mobile', 'is', 'just', 'awesome', '...']
# ['right', 'choice', 'money', 'spent', 'happy', 'really..', 'waited', 'long', 'buy', 'mobile', ',', 'loads', 'options', 'price', 'range', ',', 'select', 'choice', 'dint', 'disappoint', '...', 'camera', ',', 'battery', 'back', ',', 'fingerprint', 'face', 'recognition', ',', 'everything', 'mobile', 'awesome', '...']
# ['picture', 'quality', 'and', 'camera', 'is', 'awesome', '.', 'sound', 'is', 'pretty', 'low', 'compare', 'to', 'other', 'phones', '.', 'even', 'headphones', 'on', 'crowded', 'area', 'does', "n't", 'help', '.', 'disappointed', 'by', 'battery', 'does', "n't", 'last', 'a', 'day', 'if', 'continuous', 'internet', 'is', 'used', 'but', 'i', 'guess', 'that', 'something', 'you', 'have', 'to', 'adjust', 'as', 'per', 'price', 'and', 'feature']
# ['picture', 'quality', 'camera', 'awesome', 'sound', 'pretty', 'low', 'compare', 'phones', 'even', 'headphones', 'crowded', 'area', "n't", 'help', 'disappointed', 'battery', "n't", 'last', 'day', 'continuous', 'internet', 'used', 'guess', 'something', 'adjust', 'per', 'price', 'feature']
# ['actually', 'the', 'delivery', 'was', 'very', 'fast', ',', 'i', 'got', 'delivered', 'it', 'by', 'the', 'next', 'day', 'and', 'about', 'the', 'mobile', 'it', "'s", 'good', 'but', 'not', 'that', 'good', 'because', 'it', 'does', "n't", 'have', 'gorrilla', 'glass', 'protection', 'and', 'sound', 'quality', 'is', 'not', 'up', 'to', 'mark', 'and', 'the', 'important', 'thing', 'no', 'image', 'stabilization', '.']
# ['actually', 'delivery', 'fast', ',', 'got', 'delivered', 'next', 'day', 'mobile', "'s", 'good', 'good', "n't", 'gorrilla', 'glass', 'protection', 'sound', 'quality', 'mark', 'important', 'thing', 'image', 'stabilization']

# %%
pos_bag = []
neg_bag = []
other_bag = []

for i in range(0,len(Bag_of_Words)):
    if [Bag_of_Words[i]] in positive_list:
        pos_bag.append(Bag_of_Words[i])

        
    if [Bag_of_Words[i]] in negative_list:
        neg_bag.append(Bag_of_Words[i])
        
    else:
        other_bag.append(Bag_of_Words[i])

# %%
def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(8, 8))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

###############################################################################################################################

print("Positive words")
wordcloud_draw(pos_bag,'white')
print("Negative words")
wordcloud_draw(neg_bag)
print("Neutral words")
wordcloud_draw(other_bag, 'red')
# Out:
# Positive words
# Negative words
# Neutral words
